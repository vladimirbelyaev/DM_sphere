# %% [markdown]
# <center><img src="images/header.png"></center>
#
# <h1><center>Алгоритмы интеллектуальной обработки больших объемов данных</center></h1>
# <hr>
# <h2><center>SVM, Kernel Trick (практика)</center></h2>

# %% [markdown]
# **Срок сдачи:** 24 апреля 2017, 06:00 <br>
# **Штраф за опоздание:** -2 балла после 06:00 24 апреля, -4 балла после 06:00 1 мая, -6 баллов после 06:00 8 мая
#
# При отправлении ДЗ указывайте фамилию в названии файла<br>
#
# Не забудте создать задание в Slack через /todo.
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Семинарская часть

# %% [markdown]
# Функция `select_model` принимает на вход обучающую выборку и возвращает модель (машину опорных векторов) с наилучшими параметрами для данной выборки. Эту функцию нужно реализовать.
#
# Подбираемые параметры подели включают в себя:
# - различные функции ядра (линейное, RBF, полиномиальные разных степеней)
# - различные значения константы $C$ ($0, 0.1, 1, 10, 100, 1000, 10000$)
#
# Подбирать параметры необходимо с помощью 10-fold кросс-валидации. Сейчас в качестве заглушки функция всегда возвращает линейный SVC.

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import KFold
# Out:
# /home/vladimir/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/vladimir/anaconda2/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def select_model(x, y):
    """
    Implement some model selection strategy here:
    seek through different kernels and parameters.

    Use a validation scheme to select the best model
    
    Quality metric: accuracy

    Returns:
        SVM classifier implemented by sklearn SVC class.
    """
    best_accuracy = 0
    best_model = None
    
    kernel = 'linear'

    model = SVC(kernel=kernel)
    print "Trying model {}".format(model)
    
    accuracy = np.mean(cross_val_score(model, x, y))

    best_model = model
    best_accuracy = accuracy
    
    best_model.fit(x, y)
    print "Best model %s, with accuracy %f" % (best_model, best_accuracy)
    return best_model

# %% [markdown]
# Далее две вспомогательные функции, которые отображают данные и разделяющую поверхность

# %%
def plot_data_set(x, y, description=''):
    print "Plotting data set points"
    plt.figure(figsize=(8, 8))

    colors = np.array(['r', 'b'])[y]
    plt.title(description, fontsize='small')
    plt.scatter(x[:, 0], x[:, 1], marker='o', c=colors, s=50)
    
def plot_decision_region(x1_min, x2_min, x1_max, x2_max, clf, n_points=1000):
    print "Plotting decision region"
    x1, x2 = np.meshgrid(np.linspace(x1_min, x1_max, n_points), np.linspace(x2_min, x2_max, n_points))
    z = clf.decision_function(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape)

    plt.contour(x1, x2, z, levels=[0.0], linestyles='solid', linewidths=2.0)
    plt.contour(x1, x2, z, levels=[-1.0, 1.0], linestyles='dashed', linewidths=1.0)

# %%
def generate_linear(size=100, k=1.1, b=0.0, nl=0.1):
    print "Generating 'Linearly-separated' data set"

    x = np.random.random((size, 2))
    y = np.zeros(size, dtype=int)
    noise = np.random.randn(size) * nl
    y[x[:, 1] - (k * x[:, 0] + b) > noise] = 1

    return x, y

x, y = generate_linear()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Linearly-separated' data set
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.870711
# Plotting data set points
# Plotting decision region

# %%
def generate_concentric(size=100, r1=1.0, r2=2.0, sigma=0.3):
    print "Generating 'Concentric circles' data set"
    x = np.zeros((size, 2))
    x[:size/2, 0] = sigma * np.random.randn(size/2) + r1
    x[size/2:, 0] = sigma * np.random.randn(size/2) + r2
    x[:, 1] = (np.random.random(size) - 0.5) * 2 * np.pi
    y = np.hstack([np.zeros(size/2, dtype=int), np.ones(size/2, dtype=int)])

    z = np.zeros((size, 2))
    z[:, 0] = x[:, 0] * np.cos(x[:, 1])
    z[:, 1] = x[:, 0] * np.sin(x[:, 1])

    return z, y

x, y = generate_concentric()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Concentric circles' data set
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.652574
# Plotting data set points
# Plotting decision region

# %%
def generate_sin(size=200):
    print "Generating 'Sinus-separated' data set"

    x = np.random.random((size, 2))
    x[:, 0] = x[:, 0] * 4 * np.pi
    x[:, 1] = (x[:, 1] - 0.5) * 2
    y = np.zeros(size, dtype=int)
    y[x[:, 1] > np.sin(x[:, 0])] = 1

    return x, y

x, y = generate_sin()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Sinus-separated' data set
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.760214
# Plotting data set points
# Plotting decision region

# %%
model = SVC()
# Если запускать, poly ядро стоит выключить из param_grid, иначе будет считать долго. На моем считал 13+ минут.
# А в итоге это ядро еще и хуже.
param_grid = [{'C':[0.1,1,10,100,1000,10000], 
              'kernel':['linear']},
              {'C':[0.1,1,10,100,1000,10000], 
              'kernel':['poly'],
             'degree':[2,3]},
              {'C':[0.1,1,10,100,1000,10000], 
              'kernel':['rbf'],
             'gamma':['auto']}]
cv = KFold(n_splits = 10, shuffle = True, random_state = 123)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1,verbose=2,
                   scoring ='accuracy',cv=cv.get_n_splits(x,y))
grid.fit(x,y)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV] kernel=linear, C=0.1 ............................................
# [CV] kernel=linear, C=0.1 ............................................
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=0.1 ............................................
# [CV] ................................... kernel=linear, C=0.1 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] kernel=linear, C=10 .............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] kernel=linear, C=10 .............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] kernel=linear, C=100 ............................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] kernel=linear, C=1 ..............................................
# [CV] ..................................... kernel=linear, C=1 -   0.0s
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=linear, C=100 ............................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ................................... kernel=linear, C=100 -   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] ................................... kernel=linear, C=100 -   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=linear, C=100 ............................................
# [CV] kernel=linear, C=10 .............................................
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=linear, C=10 .............................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] .................................... kernel=linear, C=10 -   0.0s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=linear, C=100 ............................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] kernel=linear, C=100 ............................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.0s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] .................................. kernel=linear, C=1000 -   0.5s
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=linear, C=100 ............................................
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.0s
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] ................................... kernel=linear, C=100 -   0.1s
# [CV] kernel=poly, C=1, degree=2 ......................................
# [CV] kernel=linear, C=100 ............................................
# [CV] ............................. kernel=poly, C=1, degree=2 -   0.0s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ................................... kernel=linear, C=100 -   0.0s
# [CV] kernel=linear, C=100 ............................................
# [CV] ................................... kernel=linear, C=100 -   0.0s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.1s
# [CV] .................................. kernel=linear, C=1000 -   0.4s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] kernel=poly, C=0.1, degree=3 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=3 -   0.0s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] .................................. kernel=linear, C=1000 -   0.4s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.5s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] .................................. kernel=linear, C=1000 -   0.2s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] .................................. kernel=linear, C=1000 -   0.5s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.4s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] .................................. kernel=linear, C=1000 -   0.3s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.7s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] .................................. kernel=linear, C=1000 -   0.5s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] .................................. kernel=linear, C=1000 -   0.4s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.6s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] .................................. kernel=linear, C=1000 -   0.3s
# [CV] kernel=linear, C=1000 ...........................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.7s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] .................................. kernel=linear, C=1000 -   0.5s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.3s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.1s
# [CV] kernel=poly, C=10, degree=2 .....................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   1.1s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............................ kernel=poly, C=10, degree=2 -   0.2s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.6s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.6s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   0.4s
# [CV] kernel=poly, C=1, degree=3 ......................................
# [CV] ............................. kernel=poly, C=1, degree=3 -   1.2s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ................................. kernel=linear, C=10000 -   3.6s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   5.2s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   4.5s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ................................. kernel=linear, C=10000 -   2.0s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   2.7s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   6.2s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ................................. kernel=linear, C=10000 -   6.5s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   5.2s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   4.3s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ................................. kernel=linear, C=10000 -   3.6s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   4.0s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  13.5s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.5s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.5s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.9s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   2.7s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.4s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.7s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.8s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.5s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.4s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   0.9s
# [CV] kernel=poly, C=100, degree=2 ....................................
# [CV] ................................. kernel=linear, C=10000 -   6.7s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ........................... kernel=poly, C=100, degree=2 -   1.8s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ................................. kernel=linear, C=10000 -   3.7s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   8.1s
# [CV] kernel=poly, C=10, degree=3 .....................................
# [CV] ................................. kernel=linear, C=10000 -   5.8s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ................................. kernel=linear, C=10000 -   2.4s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ............................ kernel=poly, C=10, degree=3 -   8.2s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ................................. kernel=linear, C=10000 -   2.9s
# [CV] kernel=linear, C=10000 ..........................................
# [CV] ................................. kernel=linear, C=10000 -   4.4s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=0.1, degree=2 ....................................
# [CV] ........................... kernel=poly, C=0.1, degree=2 -   0.0s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  29.3s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  24.6s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  22.5s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  53.1s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ......................... kernel=poly, C=10000, degree=3 -  52.5s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  33.0s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  21.4s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1, gamma=auto .....................................
# [CV] ............................ kernel=rbf, C=1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10, gamma=auto ....................................
# [CV] ........................... kernel=rbf, C=10, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=100, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=100, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=1000, gamma=auto ..................................
# [CV] ......................... kernel=rbf, C=1000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] kernel=rbf, C=10000, gamma=auto .................................
# [CV] ........................ kernel=rbf, C=10000, gamma=auto -   0.0s
# [CV] ........................... kernel=poly, C=100, degree=3 - 1.3min
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  15.4s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] .......................... kernel=poly, C=1000, degree=3 - 1.0min
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ......................... kernel=poly, C=10000, degree=3 -  60.0s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  22.3s
# [CV] kernel=poly, C=100, degree=3 ....................................
# [CV] ........................... kernel=poly, C=100, degree=3 -  14.4s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   5.9s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  38.7s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   4.6s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   6.8s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   6.7s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   5.3s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   6.3s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   7.0s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   3.3s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   5.7s
# [CV] kernel=poly, C=1000, degree=2 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=2 -   3.9s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=3 - 1.1min
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  23.3s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ......................... kernel=poly, C=10000, degree=3 - 1.8min
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  33.1s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  52.7s
# [CV] ......................... kernel=poly, C=10000, degree=3 -  52.7s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] .......................... kernel=poly, C=1000, degree=3 - 1.5min
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ......................... kernel=poly, C=10000, degree=3 - 1.2min
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] .......................... kernel=poly, C=1000, degree=3 -  45.1s
# [CV] kernel=poly, C=1000, degree=3 ...................................
# [CV] ......................... kernel=poly, C=10000, degree=3 - 1.6min
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] .......................... kernel=poly, C=1000, degree=3 - 1.4min
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  17.7s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=3 -  46.4s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  14.7s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  12.1s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  17.7s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=3 -  40.8s
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -   8.3s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  15.8s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  22.4s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  27.7s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  19.9s
# [CV] kernel=poly, C=10000, degree=2 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=3 - 2.1min
# [CV] kernel=poly, C=10000, degree=3 ..................................
# [CV] ......................... kernel=poly, C=10000, degree=2 -  41.0s
# [CV] ......................... kernel=poly, C=10000, degree=3 - 1.6min
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [CV] kernel=rbf, C=0.1, gamma=auto ...................................
# [CV] .......................... kernel=rbf, C=0.1, gamma=auto -   0.0s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed: 13.2min finished
# GridSearchCV(cv=10, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid=[{'kernel': ['linear'], 'C': [0.1, 1, 10, 100, 1000, 10000]}, {'kernel': ['poly'], 'C': [0.1, 1, 10, 100, 1000, 10000], 'degree': [2, 3]}, {'kernel': ['rbf'], 'C': [0.1, 1, 10, 100, 1000, 10000], 'gamma': ['auto']}],
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=2)

# %%
grid.best_score_
# Out:
# 0.955

# %%
grid.best_estimator_
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # Регрессия с SVM (3 балла)

# %% [markdown]
# Загрузите набор данных из *titanium.csv*<br/>
# Мы будем решать задачу восстановления столбца 'y' по столбцу 'x'.

# %% [markdown]
# ## Визуализация данных (1 балл)

# %% [markdown]
# Выполните стандартную предобработку данных (z-score) и выведите их на графике.

# %%
df = pd.read_csv('titanium.csv')
df.head()
# Your Code Here
# Out:
#        x      y
# 0  585.0  0.644
# 1  595.0  0.622
# 2  605.0  0.638
# 3  615.0  0.649
# 4  625.0  0.652

# %%
plt.plot(df.x,df.y)

# %%
X = df.x.values.reshape(-1,1)#Чтобы его съел алгоритм(нужна 2мерный массив)
X = (X - X.mean())/X.std()
y = df.y.values
plt.plot(X,y)

# %% [markdown]
# ## Обучение моделей (2 балла)

# %% [markdown]
# Рассмотрите 3 ядра:
# * Линейное
# * Полиномиальное (degree = 3, gamma = 6, coef0 = 1)
# * RBF (gamma = 6, coef0 = 1)
#
# Во всех случаях установить ширину трубки `epsilon=0.01`
#
# Для каждого из ядер:
# 1. Пусть `C = np.logspace(-2, 2, 10)`. Постройте графики зависимости ошибки от параметра $C$ (ось графика со значениями параметра $C$ должна быть в логарифмической шкале). Ошибка измеряется как средняя абсолютная ошибка.
# 2. Для наулучшего параметра $С$ каждого из ядер постройте график с данными и предстазанием по svm
#
# В каких случаях возникает эффекты недообучения, переобучения?

# %%
from sklearn.metrics import mean_absolute_error

# %%
C = np.logspace(-2, 2, 10)
fig1 = plt.figure()
fig2 = plt.figure()
ax1 = fig1.add_subplot(1, 1, 1)
ax2 = fig2.add_subplot(1, 1, 1)
params = []
errs = []
for param in C:
    result = SVR(kernel='linear',
              epsilon=0.01, C = param).fit(X,y).predict(X)
    ax1.plot(X,result)
    params.append(param)
    errs.append(mean_absolute_error(result,y))
ax2.plot(params,errs)

# %%
C = np.logspace(-2, 2, 10)
fig1 = plt.figure()
fig2 = plt.figure()
ax1 = fig1.add_subplot(1, 1, 1)
ax2 = fig2.add_subplot(1, 1, 1)
params = []
errs = []
for param in C:
    result = SVR(coef0=1, kernel= 'poly',degree=3,gamma=6,epsilon=0.01,C=param).fit(X,y).predict(X)
    ax1.plot(X,result)
    params.append(param)
    errs.append(mean_absolute_error(result,y))
ax2.plot(params,errs)#append to array

# %%
C = np.logspace(-2, 2, 10)
fig1 = plt.figure()
fig2 = plt.figure()
ax1 = fig1.add_subplot(1, 1, 1)
ax2 = fig2.add_subplot(1, 1, 1)
params = []
errs = []
for param in C:
    result = SVR(coef0=1, kernel= 'rbf',gamma=6,epsilon=0.01,C=param).fit(X,y).predict(X)
    ax1.plot(X,result)
    params.append(param)
    errs.append(mean_absolute_error(result,y))
ax2.plot(params,errs)

# %% [markdown]
# # Определение языка слова (7 баллов)

# %% [markdown]
# В данном задании вам необходимо определить, на каком языке написано слово.
#
# Вам будет дано два текста - первые предложения произведения "Война и Мир" на английком и испанском, разбитые на слова. У слов нет общепринятого числового представления, поэтому мы предлагаем вам реализовать собственноге ядро для SVM, основанное на редакторском расстоянии или [расстоянии Левинштейна](https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9B%D0%B5%D0%B2%D0%B5%D0%BD%D1%88%D1%82%D0%B5%D0%B9%D0%BD%D0%B0).
#
# Имплементировать расстояние Леванштейна не нужно - можно взять любую доступную реализацию, например [здесь](https://github.com/toastdriven/pylev) или [здесь](https://github.com/ztane/python-Levenshtein).

# %% [markdown]
# ## Загрузка (1 балл)
#
# Загрузите данные из файлов *war_and_peace_es.txt* и *war_and_peace_en.txt*.<br/>
# В результате вы должны получить pandas.DataFrame со столбцами *index* | *word* | *label*, где *index* - это индекс pandas, *word* - это слово и *label* - это метка класса (0 или 1)

# %%
## Your Code Here
df_es = pd.read_csv('war_and_peace_es.txt',header=None)
df_es['label'] = 0
df_en = pd.read_csv('war_and_peace_en.txt',header=None)
df_en['label'] = 1

df = pd.concat([df_es, df_en])

# %%
df.rename(columns={df.columns[0]:'word'}, inplace=True)
df.head()
# Out:
#        word  label
# 0    guerra      0
# 1      pace      0
# 2       lev      0
# 3  nicoevic      0
# 4    tolstj      0

# %% [markdown]
# ## Подготовка данных (2 балла)
#
# Особенностью пользовательского ядра в sklean.SVC является то, что на вход оно должно принимать именно вектора чисел.<br/>
# В нашем случае это будут индексы соответствующих слов из корпуса. То есть вместо вектора ['treat', 'celebrit', 'prince', ...] на вход в ядро подается вектор из индексов [9209, 11145, 7735, ...] с помощью которых вы будете находить сами слова.
#
# Прежде чем мы начнем строить ядро, надо подготовить данные. Для этого:
# 1. Задайте переменную RND_SEED, которая будет использоваться в любых генераторах случайных чисел в вашем коде (обычно параметр "random_seed")
# 2. Случайным образом перемешайте и заново проиндексируйте таблицу, полученную выше (используйте методы df.sample() и df.reset_index())
# 3. Ядро может вычисляться достаточно долго, поэтому можете урезать таблицу, но оставить в ней не менее 1000 слов.
# 4. Разбейте данные на обучающую и контрольную выборку в пропорции 60/40
#
# В результате вы должны получить вектор-столбец X_train, X_test с **индексами** слов и векторы y_train, y_test с метками классов.

# %%
from sklearn.cross_validation import train_test_split

# %%
RND_SEED = 133
df = df.sample(frac = 1, random_state = RND_SEED)
df = df.reset_index(drop = True)
df = df.iloc[:1500,:]
df.head()
# Out:
#          word  label
# 0      pierre      1
# 1        said      1
# 2         was      1
# 3        soon      1
# 4  petersburg      1

# %%
X_train, X_test, y_train, y_test = train_test_split(np.arange(df.values.shape[0]), df.iloc[:,1].values, test_size = 0.4, random_state = RND_SEED)

# %%
print X_train[:5], y_train[:5]
df.iloc[X_train[:5],:]
# Out:
# [ 888  949  923  309 1033] [1 0 0 1 0]
#          word  label
# 888       the      1
# 949   proprio      0
# 923      fren      0
# 309       are      1
# 1033      cos      0

# %% [markdown]
# ## Расчет ядра (3 балла)
#
# Некоторые указания по составлению пользовательского ядра можно найти [здесь](http://stackoverflow.com/questions/26962159/how-to-use-a-custom-svm-kernel).
#
# Если в двух словах:<br/>
# Функция, реазлизующая расчет ядра должна принимать две матрицы $U$ и $V$ с признаковым описанием объектов (во време обучения они обе относятся к обучающей выборке, а во время применения - одна матрица относится к обучающей выборке, а другая к контрольной).
#
# В результате, функция должна возвращать матрицу ядра $G_{ij} = K(U_i, V_j)$.
#
# Таким образом, в этом задании вам надо:
# 1. Написать функцию *string_kernel(U, V)*, расчитывающее матрицу ядра $G_{ij}$
# 2. Визуализировать матрицу только для обучающей выборки (функция plt.imshow()).
#
# **ВАЖНО**<br/>
# На лекции мы рассмотрели, что ядро должно обладать определенными свойствами, поэтому не получится рассчитать $G_{ij}$ как расстояние Левинштейна между словами $\text{word}_i$ и $\text{word}_j$.<br/>
# Вместо этого используйте какое-нибудь готовое ядро, зависящее от расстояние между объектами.

# %%
import Levenshtein, itertools
print Levenshtein.distance('work', 'home')
# Out:
# 3

# %%
def string_kernel(U, V):
    res = np.empty([U.shape[0], V.shape[0]])
    df_left = df.iloc[U,0].values
    df_right = df.iloc[V,0].values
    for i, j in itertools.product(range(U.shape[0]), range(V.shape[0])):
        res[i, j] = Levenshtein.distance(df_left[i], df_right[j])
    return 1 / (res + 1) ** 4

G = string_kernel(X_train, X_train)

# %%
plt.imshow(G)

# %% [markdown]
# ## Оценка качества (1 балл)
#
# Обучите метод опорных векторов с различными значениями параметра штрафа $C$.<br/>
# Для каждого значения выведите accuracy на обучащюей и контрольной выборке.
#
# Постарайтесь достичь качества в 70% на тестовой выборке

# %%
from sklearn.metrics import accuracy_score

# %%
c_lst = np.logspace(-3,3,15)
string_kernel_test = string_kernel(X_test, X_train)
accuracy_lst_train = []
accuracy_lst_test = []
for c in c_lst:
    my_clf = SVC(C = c, kernel = 'precomputed').fit(G, y_train)
    result_train = my_clf.predict(G)
    result_test = my_clf.predict(string_kernel_test)
    print 'C =', c
    print 'accuracy_score_train =',accuracy_score(
        result_train, y_train), '\t accuracy_score_test =', accuracy_score(
        result_test, y_test)
    accuracy_lst_train.append(accuracy_score(result_train, y_train))
    accuracy_lst_test.append(accuracy_score(result_test, y_test))
# Out:
# C = 0.001
# accuracy_score_train = 0.528888888889 	 accuracy_score_test = 0.546666666667
# C = 0.00268269579528
# accuracy_score_train = 0.528888888889 	 accuracy_score_test = 0.546666666667
# C = 0.00719685673001
# accuracy_score_train = 0.528888888889 	 accuracy_score_test = 0.546666666667
# C = 0.0193069772888
# accuracy_score_train = 0.528888888889 	 accuracy_score_test = 0.546666666667
# C = 0.0517947467923
# accuracy_score_train = 0.554444444444 	 accuracy_score_test = 0.588333333333
# C = 0.138949549437
# accuracy_score_train = 0.656666666667 	 accuracy_score_test = 0.676666666667
# C = 0.372759372031
# accuracy_score_train = 0.768888888889 	 accuracy_score_test = 0.733333333333
# C = 1.0
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.801666666667
# C = 2.68269579528
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 7.19685673001
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 19.3069772888
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 51.7947467923
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 138.949549437
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 372.759372031
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667
# C = 1000.0
# accuracy_score_train = 0.991111111111 	 accuracy_score_test = 0.811666666667

# %%
plt.figure()
plt.plot(np.log10(c_lst), accuracy_lst_train, np.log10(c_lst), accuracy_lst_test)
# Out:
# [<matplotlib.lines.Line2D at 0x7f3b0957e650>,
#  <matplotlib.lines.Line2D at 0x7f3b0957e850>]

# %%
print 'max_accuracy', np.max(accuracy_lst_test)
print 'c_max_accuracy', c_lst[np.argmax(accuracy_lst_test)]
# Out:
# max_accuracy 0.811666666667
# c_max_accuracy 2.68269579528
